# %% [markdown]
# ## Using TextRazor for Named Entities (and topics)<a name="_using textrazor for named entities (and topics)"></a>

# %% [markdown]
# Here is the site: https://www.textrazor.com/
#
# You need to
# `pip install textrazor`
# at the command line.
#
# We are allowed to use my key for a limited number of queries per day. Don't abuse it.
#
# Documentation: https://www.textrazor.com/tutorials

# %%
KEY = "see code in Module on BS"

# %%
import textrazor

import nlp_utilities as mytools

# %%
textrazor.api_key = KEY

# %%
client = textrazor.TextRazor(extractors=["entities", "topics"])
client.set_classifiers(["textrazor_newscodes"])

# %%
files = mytools.get_filenames("data/movie_reviews/positive/")

# %%
files
# Out:
# ['data/movie_reviews/positive/cv670_tok-24009.txt',
#  'data/movie_reviews/positive/cv671_tok-10077.txt',
#  'data/movie_reviews/positive/cv672_tok-12350.txt',
#  'data/movie_reviews/positive/cv673_tok-6552.txt',
#  'data/movie_reviews/positive/cv674_tok-11591.txt',
#  'data/movie_reviews/positive/cv675_tok-11864.txt',
#  'data/movie_reviews/positive/cv676_tok-19999.txt',
#  'data/movie_reviews/positive/cv677_tok-11867.txt',
#  'data/movie_reviews/positive/cv678_tok-24352.txt',
#  'data/movie_reviews/positive/cv679_tok-13972.txt',
#  'data/movie_reviews/positive/cv680_tok-18142.txt',
#  'data/movie_reviews/positive/cv681_tok-28559.txt',
#  'data/movie_reviews/positive/cv682_tok-21593.txt',
#  'data/movie_reviews/positive/cv683_tok-12295.txt',
#  'data/movie_reviews/positive/cv684_tok-10367.txt',
#  'data/movie_reviews/positive/cv685_tok-11187.txt',
#  'data/movie_reviews/positive/cv686_tok-22284.txt',
#  'data/movie_reviews/positive/cv687_tok-20347.txt',
#  'data/movie_reviews/positive/cv688_tok-10047.txt',
#  'data/movie_reviews/positive/cv689_tok-8825.txt',
#  'data/movie_reviews/positive/cv690_tok-23617.txt',
#  'data/movie_reviews/positive/cv691_tok-11491.txt',
#  'data/movie_reviews/positive/cv692_tok-24295.txt',
#  'data/movie_reviews/positive/cv693_tok-16307.txt',
#  'data/movie_reviews/positive/cv694_tok-18628.txt',
#  'data/movie_reviews/positive/cv695_tok-12873.txt',
#  'data/movie_reviews/positive/cv696_tok-10835.txt',
#  'data/movie_reviews/positive/cv697_tok-29325.txt',
#  'data/movie_reviews/positive/cv698_tok-27735.txt',
#  'data/movie_reviews/positive/cv699_tok-10425.txt']

# %%
texts = mytools.load_texts_as_string(files)

# %%
texts[files[0]]
# Out:
# 'rated on a 4-star scale screening venue : odoen ( liverpool city centre ) released in the uk by uip on april 7 , 2000 ; certificate 15 ; 126 minutes ; country of origin usa ; aspect ratio 1 . 85 : 1 directed by stephen soderbergh ; produced by danny devito , michael shamberg , stacey sher . written by susannah grant . photographed by ed lachmann ; edited by anne v . coates . it\'s astounding , how many of us turn into lawyers when we get wrapped up in cases . i remember the louise woodward affair , for example , when i knew all the evidence from the courtroom pictures on tv , and was able to reel off detailed arguments crushing people who had just looked at her and assumed she was guilty . passion about justice is what makes people consider law careers ; it chills me when i see sell-outs trying to condemn obviously innocent people , or using dishonest tactics to help the guilty . stephen soderbergh\'s " erin brockovich " is a brilliant story of anger turning into courtroom skills ; a david versus goliath-style expos in the great tradition of " silkwood " , " a civil action " and " the insider " . at its centre is a woman with no judiciary training or expertise , whose mind was not complicated with red tape or histories of statutes , and whose discoveries and simple logical interpretations helped small-time lawyers win one of the biggest lawsuits in american history . her name , of course , is erin brockovich ( julia roberts ) , and when we meet her in the opening scenes of this film , she\'s just a struggling single mother who has failed to win a personal injury settlement . soon after , she hustles her way into a filing job at the firm of her solicitor . the boss , ed masry ( albert finney ) , objects , but erin makes her services hard to refuse : " i need a job . don\'t make me beg . if it doesn\'t work out , fire me . " when handling the real estate documents of a town in california , erin notices something odd -- they all include medical records . researching this further , she stumbles on the information that the area\'s water supplier , pacific gas & electric , has been using a dangerous chemical known as \'hexavalent chromium 3\' in their pipes . \'chromium 3\' can penetrate the body to cause pretty much any illness , including all forms of cancer . what\'s especially horrific is that pg&e knew about the hazards of their water and misinformed its customers that chromium was good for them . the people took the company\'s word , even when they all started to get sick , until erin brockovich revealed her findings , and used her common touch to encourage the folks to stand up and take legal action . brockovich is not always a likeable character . at the start of the movie , when no job interviewers will look past her lack of a resum or qualifications , her feeling of victimisation is preposterous . she seems to think anyone who isn\'t stuck in the poverty trap must be some sort of snob . and she displays gross arrogance when defending her wardrobe , which is made up of mini-skirts , tight boob tubes and high-heeled boots . " as long as i have one ass instead of two , " she tells masry when he points out that his office has a dress code , " i\'ll wear what i god damn well please . " but none of these flaws take away from her achievement , which is that she worked hard , taught herself some tough skills , became a great friend and advocate for victims of an abominable crime , and managed to raise a family at the same time . this is one of roberts\'s most impressive performances , her best since " pretty woman " ( 1990 ) , because she really does look affected by the pressures her character has to cope with . she allows herself to be vulnerable , with a voice that can quiver and stumble . she doesn\'t always have the answers , and could break down at any minute . there are one or two irritating episodes of grandstanding , where she rattles off snappy , heroic speeches that probably took the screenwriter hours to write ; but t ...

# %%
response = client.analyze(texts[files[0]])

# %%
list(response.entities())
# Out:
# [TextRazor Entity b'louise woodward' at positions [99, 100],
#  TextRazor Entity b'ed lachmann' at positions [67, 68],
#  TextRazor Entity b'coates' at positions [75],
#  TextRazor Entity b'anne v' at positions [72, 73],
#  TextRazor Entity b'Michael Shamberg' at positions [54, 55],
#  TextRazor Entity b'roberts' at positions [693],
#  TextRazor Entity b'United International Pictures' at positions [19],
#  TextRazor Entity b'Aspect ratio' at positions [37, 38],
#  TextRazor Entity b'Liverpool' at positions [10],
#  TextRazor Entity b'4-star' at positions [3],
#  TextRazor Entity b'odoen -LRB- liverpool' at positions [8, 9, 10],
#  TextRazor Entity b'Solicitor' at positions [324],
#  TextRazor Entity b'2000-04-07T00:00:00.000-04:00' at positions [21, 22, 23, 24],
#  TextRazor Entity b'Edward L. Masry' at positions [329, 330],
#  TextRazor Entity b'Albert Finney' at positions [332, 333],
#  TextRazor Entity b'erin' at positions [382],
#  TextRazor Entity b'david' at positions [194],
#  TextRazor Entity b'Erin Brockovich (film)' at positions [520],
#  TextRazor Entity b'Silkwood' at positions [204],
#  TextRazor Entity b'Lawsuit' at positions [209, 210],
#  TextRazor Entity b'1' at positions [43],
#  TextRazor Entity b'Stacey Sher' at positions [57, 58],
#  TextRazor Entity b'1990-01-01T00:00:00.000-05:00' at positions [707],
#  TextRazor Entity b'2000-01-01T00:00:00.000-05:00' at positions [926],
#  TextRazor Entity b'3' at positions [425, 426],
#  TextRazor Entity b'3' at positions [433, 434],
#  TextRazor Entity b'126' at positions [29, 30],
#  TextRazor Entity b'ian waldron-mantgani' at positions [927, 928],
#  TextRazor Entity b'soderbergh' at positions [871],
#  TextRazor Entity b'Susannah Grant' at positions [62, 63],
#  TextRazor Entity b'Liverpool City Centre' at positions [10, 11, 12],
#  TextRazor Entity b'Danny DeVito' at positions [51, 52],
#  TextRazor Entity b'Erin Brockovich (film)' at positions [179, 180],
#  TextRazor Entity b'United States' at positions [35],
#  TextRazor Entity b'United States' at positions [261],
#  TextRazor Entity b'Lawsuit' at positions [853, 854],
#  TextRazor Entity b'Copyright' at positions [922],
#  TextRazor Entity b'Silkwood' at positions [842],
#  TextRazor Entity b'Miniskirt' at positions [592],
#  TextRazor Entity b'Julia Roberts' at positions [274, 275],
#  TextRazor Entity b'Hexavalent chromium' at positions [423, 424],
#  TextRazor Entity b'Chromium' at positions [424],
#  TextRazor Entity b'Pacific Gas and Electric Company' at positions [409, 410, 411, 412],
#  TextRazor Entity b'Dress code' at positions [626, 627],
#  TextRazor Entity b'Out of Sight' at positions [885, 886, 887],
#  TextRazor Entity b'Pretty Woman' at positions [703, 704],
#  TextRazor Entity b'Steven Soderbergh' at positions [46, 47],
#  TextRazor Entity b'erin' at positions [339],
#  TextRazor Entity b'United Kingdom' at positions [16, 17],
#  TextRazor Entity b'15' at positions [27],
#  TextRazor Entity b'Erin Brockovich (film)' at positions [807, 808],
#  TextRazor Entity b'1' at positions [39],
#  TextRazor Entity b'85' at positions [41],
#  TextRazor Entity b'Lawyer' at positions [87],
#  TextRazor Entity b'Erin Brockovich (film)' at positions [497, 498],
#  TextRazor Entity b'Chromium' at positions [473],
#  TextRazor Entity b'Hypertext Transfer Protocol' at positions [948],
#  TextRazor Entity b'AOL' at positions [954],
#  TextRazor Entity b'Steven Soderbergh' at positions [175, 176],
#  TextRazor Entity b'Screenwriter' at positions [780],
#  TextRazor Entity b'United Kingdom' at positions [938, 939],
#  TextRazor Entity b'California' at positions [380],
#  TextRazor Entity b'Documentary film' at positions [904],
#  TextRazor Entity b'Red tape' at positions [237, 238],
#  TextRazor Entity b'Crime' at positions [676],
#  TextRazor Entity b'Personal injury' at positions [304, 305],
#  TextRazor Entity b'Lawsuit' at positions [259],
#  TextRazor Entity b'Statute' at positions [242],
#  TextRazor Entity b'God' at positions [635],
#  TextRazor Entity b'Erin Brockovich (film)' at positions [271, 272],
#  TextRazor Entity b'Pacific Gas and Electric Company' at positions [458, 459, 460],
#  TextRazor Entity b'Judiciary' at positions [226],
#  TextRazor Entity b'Cancer' at positions [450],
#  TextRazor Entity b'Snob' at positions [575],
#  TextRazor Entity b'Poverty trap' at positions [568, 569],
#  TextRazor Entity b'Poverty' at positions [568],
#  TextRazor Entity b'Lawyer' at positions [253],
#  TextRazor Entity b'Medical record' at positions [390, 391],
#  TextRazor Entity b'Victimisation' at positions [553],
#  TextRazor Entity b'Chemical substance' at positions [419],
#  TextRazor Entity b'Chromium' at positions [432],
#  TextRazor Entity b'Pacific Ocean' at positions [409]]

# %%
entities = list(response.entities())
entities.sort(key=lambda x: x.relevance_score, reverse=True)
seen = set()
for entity in entities:
    if entity.id not in seen:
        print(entity.id, entity.relevance_score, entity.confidence_score, entity.freebase_types)
        seen.add(entity.id)
# Out:
# Erin Brockovich (film) 0.7564 13.43 ['/award/award_winning_work', '/award/award_nominated_work', '/award/ranked_item', '/film/film', '/media_common/netflix_title']
# Pacific Gas and Electric Company 0.4017 2.287 ['/business/employer', '/business/business_operation', '/exhibitions/exhibition_sponsor', '/business/issuer', '/organization/organization']
# Lawsuit 0.3914 7.133 ['/book/book_subject', '/media_common/quotation_subject', '/internet/website_category']
# Steven Soderbergh 0.3777 6.674 ['/award/award_winner', '/film/cinematographer', '/people/person', '/book/author', '/tv/tv_program_creator', '/film/writer', '/film/editor', '/tv/tv_director', '/organization/organization_founder', '/celebrities/celebrity', '/film/person_or_entity_appearing_in_film', '/award/award_nominee', '/film/actor', '/tv/tv_actor', '/film/producer', '/film/director', '/theater/theater_director', '/tv/tv_producer']
# Lawyer 0.3547 5.662 ['/book/book_subject', '/media_common/quotation_subject', '/business/industry', '/organization/organization_type', '/fictional_universe/character_occupation', '/people/profession', '/business/customer', '/people/group', '/organization/contact_category', '/education/field_of_study', '/organization/organization_sector', '/business/job_title']
# Edward L. Masry 0.3443 2.01 ['/people/person', '/people/deceased_person']
# Michael Shamberg 0.3396 4.753 ['/people/deceased_person', '/film/producer', '/film/actor', '/book/author', '/film/director', '/organization/organization_founder', '/award/award_nominee', '/people/person']
# Victimisation 0.3359 1.589 ['/book/book_subject']
# Julia Roberts 0.3276 7.617 ['/film/actor', '/people/person', '/people/family_member', '/tv/tv_producer', '/book/book_subject', '/tv/tv_program_guest', '/award/award_nominee', '/music/featured_artist', '/people/measured_person', '/music/artist', '/tv/tv_actor', '/tv/tv_personality', '/celebrities/celebrity', '/award/ranked_item', '/theater/theater_actor', '/film/person_or_entity_appearing_in_film', '/award/award_winner', '/film/producer']
# Personal injury 0.3184 2.487 ['/organization/organization_sector', '/book/book_subject']
# Out of Sight 0.317 2.431 ['/award/ranked_item', '/award/award_nominated_work', '/award/award_winning_work', '/media_common/adaptation', '/media_common/netflix_title', '/film/film']
# Documentary film 0.2974 4.503 ['/media_common/media_genre', '/organization/organization_sector', '/tv/tv_series_season', '/education/field_of_study', '/film/film_festival_focus', '/internet/website_category', '/film/film_subject', '/film/film_genre', '/theater/theater_genre', '/media_common/literary_genre', '/tv/tv_genre', '/book/book_subject', '/broadcast/genre', '/media_common/netflix_genre', '/tv/tv_subject', '/film/content_rating', '/award/award_discipline']
# Hexavalent chromium 0.2846 6.443 ['/chemistry/chemical_compound']
# Albert Finney 0.2651 5.445 ['/music/artist', '/influence/influence_node', '/film/producer', '/tv/tv_actor', '/tv/tv_producer', '/film/director', '/award/award_nominee', '/theater/theater_actor', '/people/person', '/film/person_or_entity_appearing_in_film', '/award/award_winner', '/film/actor']
# Danny DeVito 0.2631 7.724 ['/influence/influence_node', '/film/producer', '/award/award_winner', '/film/director', '/tv/tv_director', '/tv/tv_actor', '/film/person_or_entity_appearing_in_film', '/film/actor', '/people/person', '/tv/tv_personality', '/tv/tv_program_guest', '/food/diet_follower', '/award/award_nominee', '/tv/tv_producer']
# Pretty Woman 0.2509 2.371 ['/award/award_nominated_work', '/award/award_winning_work', '/media_common/adaptation', '/film/film', '/award/ranked_item', '/media_common/netflix_title']
# Solicitor 0.2502 3.439 ['/book/book_subject', '/organization/organization_sector', '/organization/contact_category', '/fictional_universe/character_occupation', '/organization/organization_type', '/people/profession']
# Cancer 0.243 4.133 ['/medicine/disease_cause', '/book/book_subject', '/tv/tv_subject', '/book/periodical_subject', '/medicine/risk_factor', '/fictional_universe/medical_condition_in_fiction', '/people/cause_of_death', '/organization/organization_sector', '/medicine/icd_9_cm_classification', '/education/field_of_study', '/media_common/quotation_subject', '/film/film_subject', '/medicine/disease']
# Poverty 0.2415 3.024 ['/film/film_subject', '/education/field_of_study', '/cvg/computer_game_subject', '/medicine/risk_factor', '/influence/influence_node', '/book/book_subject']
# Miniskirt 0.2248 2.962 ['/business/product_category', '/fashion/garment']
# Judiciary 0.2178 4.273 ['/government/governmental_body', '/location/capital_category', '/book/book_subject']
# Susannah Grant 0.1998 2.191 ['/tv/tv_program_creator', '/people/person', '/book/author', '/film/person_or_entity_appearing_in_film', '/film/actor', '/award/award_winner', '/tv/tv_writer', '/film/writer', '/award/award_nominee', '/film/director', '/tv/tv_director', '/tv/tv_actor']
# AOL 0.1995 3.705 ['/internet/website_owner', '/business/issuer', '/computer/protocol_provider', '/business/business_operation', '/business/consumer_company', '/book/newspaper_owner', '/book/book_subject', '/organization/organization', '/venture_capital/venture_investor', '/cvg/cvg_publisher', '/business/employer', '/venture_capital/venture_funded_company', '/award/award_nominee', '/organization/organization_partnership', '/award/award_winner', '/computer/software_developer', '/business/customer']
# Crime 0.1979 1.158 ['/book/book_subject', '/broadcast/genre', '/tv/tv_series_season', '/film/film_genre', '/people/professional_field', '/media_common/media_genre', '/tv/tv_genre', '/radio/radio_subject']
# Liverpool 0.1925 3.244 ['/location/administrative_division', '/exhibitions/exhibition_subject', '/fictional_universe/fictional_setting', '/organization/organization_scope', '/book/book_subject', '/location/uk_metropolitan_borough', '/rail/railway_terminus', '/protected_sites/listed_site', '/location/capital_of_administrative_division', '/government/governmental_jurisdiction', '/location/dated_location', '/location/citytown', '/travel/travel_destination', '/sports/sports_team_location', '/location/location', '/location/statistical_region', '/location/uk_statistical_location', '/film/film_location', '/periodicals/newspaper_circulation_area', '/symbols/name_source']
# Chromium 0.1902 4.822 ['/medicine/drug_ingredient', '/chemistry/chemical_element', '/engineering/material', '/medicine/condition_prevention_factors', '/medicine/drug']
# Screenwriter 0.1871 4.02 ['/fictional_universe/character_occupation', '/people/profession', '/film/film_job']
# Medical record 0.1823 1.137 []
# United States 0.1741 37.8 ['/tv/tv_location', '/sports/sports_team_location', '/event/speech_topic', '/organization/organization_sector', '/government/governmental_jurisdiction', '/olympics/olympic_participating_country', '/location/administrative_division', '/location/country', '/sports/sport_country', '/periodicals/newspaper_circulation_area', '/location/location', '/travel/travel_destination', '/media_common/quotation_subject', '/meteorology/cyclone_affected_area', '/biology/breed_origin', '/exhibitions/exhibition_subject', '/religion/religious_leadership_jurisdiction', '/radio/radio_subject', '/location/dated_location', '/organization/contact_category', '/organization/organization_founder', '/film/film_location', '/location/statistical_region', '/business/business_location', '/media_common/quotation_addressee', '/government/government', '/military/military_unit_place_of_origin', '/fictional_universe/fictional_setting', '/symbols/flag_referent', '/symbols/name_source', '/book/book_subject', '/business/employer', '/organization/organization_member', '/business/asset_owner', '/film/film_subject', '/food/beer_country_region', '/organization/organization_scope', '/cvg/computer_game_region', '/military/military_combatant', '/law/court_jurisdiction_area']
# United Kingdom 0.1725 4.571 ['/sports/sport_country', '/organization/contact_category', '/food/beer_country_region', '/government/governmental_jurisdiction', '/location/uk_statistical_location', '/business/employer', '/location/dated_location', '/organization/organization_scope', '/royalty/kingdom', '/organization/organization_member', '/sports/sports_team_location', '/media_common/netflix_genre', '/book/periodical_subject', '/military/military_combatant', '/location/location', '/location/statistical_region', '/location/administrative_division', '/biology/breed_origin', '/symbols/flag_referent', '/fictional_universe/fictional_setting', '/tv/tv_location', '/film/film_location', '/organization/organization_founder', '/periodicals/newspaper_circulation_area', '/location/country', '/business/business_location', '/olympics/olympic_participating_country', '/cvg/computer_game_region', '/law/court_jurisdiction_area', '/book/book_subject']
# Stacey Sher 0.1713 3.686 ['/film/actor', '/people/person', '/film/producer', '/award/award_nominee']
# Dress code 0.1634 1.874 []
# Red tape 0.1633 1.931 ['/business/brand']
# California 0.1588 3.007 ['/symbols/flag_referent', '/sports/sports_team_location', '/fictional_universe/fictional_setting', '/periodicals/newspaper_circulation_area', '/location/us_state', '/government/political_district', '/government/government_agency', '/film/film_location', '/wine/wine_region', '/location/dated_location', '/organization/organization_scope', '/location/location', '/book/book_subject', '/location/statistical_region', '/location/administrative_division', '/organization/organization', '/military/military_unit_place_of_origin', '/law/court_jurisdiction_area', '/meteorology/cyclone_affected_area', '/government/governmental_jurisdiction', '/symbols/name_source', '/travel/travel_destination']
# Silkwood 0.1519 1.994 ['/award/award_nominated_work', '/media_common/netflix_title', '/award/award_winning_work', '/film/film', '/award/ranked_item']
# Copyright 0.1333 3.692 ['/law/legal_subject', '/computer/software_license', '/computer/content_license', '/book/periodical_subject', '/book/book_subject']
# God 0.1329 1.51 ['/fictional_universe/person_in_fiction', '/book/book_subject', '/film/film_subject', '/religion/deity', '/fictional_universe/character_species']
# Snob 0.1135 1.414 ['/book/book_subject']
# Poverty trap 0.1064 3.303 []
# Statute 0.1059 4.502 []
# Chemical substance 0.1048 2.37 ['/book/book_subject']
# Hypertext Transfer Protocol 0.09218 3.59 ['/computer/internet_protocol', '/internet/protocol', '/internet/protocol', '/internet/api', '/computer/internet_protocol', '/law/invention']
# Pacific Ocean 0.09045 3.023 ['/geography/geographical_feature', '/film/film_location', '/book/book_subject', '/meteorology/cyclone_affected_area', '/people/place_of_interment', '/geography/body_of_water', '/location/location']
# United International Pictures 0.09015 2.222 ['/organization/organization', '/film/film_distributor', '/business/business_operation', '/film/film_company', '/business/employer']
# Liverpool City Centre 0.0859 2.61 ['/location/location']
# Aspect ratio 0.05494 1.726 []
# louise woodward 0 0.5 ['/people/person']
# ed lachmann 0 0.5 ['/people/person']
# coates 0 0.5 ['/people/person']
# anne v 0 0.5 ['/people/person']
# roberts 0 0.5 ['/people/person']
# 4-star 0 0.5 ['/organization/organization']
# odoen -LRB- liverpool 0 0.5 ['/organization/organization']
# 2000-04-07T00:00:00.000-04:00 0 0.5 []
# erin 0 0.5 ['/people/person']
# david 0 0.5 ['/people/person']
# 1 0 0.5 []
# 1990-01-01T00:00:00.000-05:00 0 0.5 []
# 2000-01-01T00:00:00.000-05:00 0 0.5 []
# 3 0 0.5 []
# 126 0 0.5 []
# ian waldron-mantgani 0 0.5 ['/people/person']
# soderbergh 0 0.5 ['/people/person']
# 15 0 0.5 []
# 85 0 0.5 []

# %%
for topic in response.topics():
    if topic.score > 0.5:
        print(topic.label, topic.score)
# Out:
# Erin Brockovich (film) 1
# Erin Brockovich 0.6715
# Steven Soderbergh 0.6689
# Pacific Gas and Electric Company 0.6487
# Lawyer 0.6281
# Law 0.6175
# Lawsuit 0.6075
# Justice 0.5833
# Social institutions 0.5271
# Government 0.5047

# %%
for category in response.categories():
    print(category.category_id, category.label, category.score)
# Out:
# 02002001 crime, law and justice>judiciary (system of justice)>lawyer 0.5589
# 02008001 crime, law and justice>trials>litigation 0.5073
# 02002000 crime, law and justice>judiciary (system of justice) 0.5013
# 01005000 arts, culture and entertainment>cinema 0.4047
# 02006000 crime, law and justice>laws 0.3924
# 02008000 crime, law and justice>trials 0.3915
# 02000000 crime, law and justice 0.3867
# 02009000 crime, law and justice>prosecution 0.3845
# 01013000 arts, culture and entertainment>photography 0.3839
# 04010003 economy, business and finance>media>cinema industry 0.3502

# %% [markdown]
# # Twitter API<a name="_twitter api"></a><a name="_twitter api"></a>

# %% [markdown]
# If you want to use twitter's API to collect your own tweets about a subject, here is a good document:
#
# http://socialmedia-class.org/twittertutorial.html
#
# It requires you to create your own API keys with your own twitter account.
#
# Note: You can 'pip install twitter' instead of the setup.py instructions shown there.

# %%
import json
import tweepy


# Variables that contains the user credentials to access Twitter API
# register for these at apps.twitter.com.  You need to register to get your own.
ACCESS_TOKEN = 'yours here'
ACCESS_SECRET = 'yours here'
CONSUMER_KEY = 'yours here'
CONSUMER_SECRET = 'yours here'

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

api = tweepy.API(auth)

# %%
query = '#python'
max_tweets = 10
searched_tweets = [status for status in tweepy.Cursor(api.search, q=query).items(max_tweets)]

# %%
searched_tweets
# Out:
# [Status(metadata={'result_type': 'recent', 'iso_language_code': 'en'}, user=User(statuses_count=328, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_text_color='333333', name='Rubén Valseca', profile_use_background_image=True, friends_count=185, default_profile=True, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/670737658444926976/f19pwCqw_normal.jpg', notifications=False, followers_count=216, id=885512094, translator_type='none', profile_background_color='C0DEED', time_zone=None, geo_enabled=False, protected=False, location='Madrid', _json={'statuses_count': 328, 'entities': {'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'Rubén Valseca', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 185, 'profile_image_url': 'http://pbs.twimg.com/profile_images/670737658444926976/f19pwCqw_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/670737658444926976/f19pwCqw_normal.jpg', 'has_extended_profile': False, 'favourites_count': 496, 'default_profile_image': False, 'time_zone': None, 'followers_count': 216, 'created_at': 'Tue Oct 16 23:08:47 +0000 2012', 'listed_count': 15, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_color': 'C0DEED', 'url': None, 'utc_offset': None, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/885512094/1478122147', 'lang': 'es', 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'Madrid', 'screen_name': 'rubnvp', 'profile_background_tile': False, 'id_str': '885512094', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'is_translator': False, 'id': 885512094, 'follow_request_sent': False, 'description': 'Playing in the full-stack to build awesome stuff :D. JS & Python writer.\n@Style_Sage developer. @frontfest organizer.'}, profile_image_url='http://pbs.twimg.com/profile_images/670737658444926976/f19pwCqw_normal.jpg', profile_sidebar_fill_color='DDEEF6', following=False, follow_request_sent=False, description='Playing in the full-stack to build awesome stuff :D. JS & Python writer.\n@Style_Sage developer. @frontfest organizer.', entities={'description': {'urls': []}}, id_str='885512094', profile_link_color='1DA1F2', favourites_count=496, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/885512094/1478122147', created_at=datetime.datetime(2012, 10, 16, 23, 8, 47), listed_count=15, verified=False, has_extended_profile=False, url=None, _api=<tweepy.api.API object at 0x114514da0>, lang='es', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', is_translation_enabled=False, screen_name='rubnvp', profile_background_tile=False, utc_offset=None, profile_sidebar_border_color='C0DEED', is_translator=False), entities={'user_mentions': [{'name': 'Pooya Parsa', 'id_str': '1605189510', 'indices': [3, 9], 'screen_name': '_pi0_', 'id': 1605189510}, {'name': 'Vue.js', 'id_str': '2292889800', 'indices': [58, 64], 'screen_name': 'vuejs', 'id': 2292889800}, {'name': 'Nuxt.js', 'id_str': '800044778901618688', 'indices': [69, 77], 'screen_name': 'nuxt_js', 'id': 800044778901618688}], 'symbols': [], 'urls': [], 'hashtags': [{'indices': [89, 96], 'text': 'Python'}]}, created_at=datetime.datetime(2018, 2, 12, 11, 16, 41), is_quote_status=False, _json={'user': {'statuses_count': 328, 'entities': {'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'Rubén Valseca', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 185, 'profile_ima ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'en'}, user=User(statuses_count=66195, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_text_color='000000', name='Python Flux', profile_use_background_image=False, friends_count=1859, default_profile=False, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/726714034066706433/5NWdOzpJ_normal.jpg', notifications=False, followers_count=3710, id=726709023563747328, translator_type='none', profile_background_color='000000', time_zone='Pacific Time (US & Canada)', geo_enabled=False, protected=False, location='', _json={'statuses_count': 66195, 'entities': {'description': {'urls': []}}, 'default_profile': False, 'profile_text_color': '000000', 'name': 'Python Flux', 'profile_use_background_image': False, 'notifications': False, 'profile_link_color': '1B95E0', 'friends_count': 1859, 'profile_image_url': 'http://pbs.twimg.com/profile_images/726714034066706433/5NWdOzpJ_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/726714034066706433/5NWdOzpJ_normal.jpg', 'has_extended_profile': False, 'favourites_count': 3, 'default_profile_image': False, 'time_zone': 'Pacific Time (US & Canada)', 'followers_count': 3710, 'created_at': 'Sun May 01 09:45:07 +0000 2016', 'listed_count': 387, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_color': '000000', 'url': None, 'utc_offset': -28800, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/726709023563747328/1504969738', 'lang': 'en', 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': '', 'screen_name': 'pythonbot_', 'profile_background_tile': False, 'id_str': '726709023563747328', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'is_translator': False, 'id': 726709023563747328, 'follow_request_sent': False, 'description': 'I retweet everything about #Python programming language !'}, profile_image_url='http://pbs.twimg.com/profile_images/726714034066706433/5NWdOzpJ_normal.jpg', profile_sidebar_fill_color='000000', following=False, follow_request_sent=False, description='I retweet everything about #Python programming language !', entities={'description': {'urls': []}}, id_str='726709023563747328', profile_link_color='1B95E0', favourites_count=3, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/726709023563747328/1504969738', created_at=datetime.datetime(2016, 5, 1, 9, 45, 7), listed_count=387, verified=False, has_extended_profile=False, url=None, _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', is_translation_enabled=False, screen_name='pythonbot_', profile_background_tile=False, utc_offset=-28800, profile_sidebar_border_color='000000', is_translator=False), entities={'user_mentions': [], 'symbols': [], 'urls': [{'display_url': 'zpy.io/66119f6f', 'expanded_url': 'http://zpy.io/66119f6f', 'url': 'https://t.co/yONK09frgl', 'indices': [43, 66]}], 'hashtags': [{'indices': [67, 76], 'text': 'learning'}, {'indices': [77, 84], 'text': 'python'}, {'indices': [85, 96], 'text': 'pythonbot_'}]}, created_at=datetime.datetime(2018, 2, 12, 11, 16, 24), is_quote_status=False, _json={'user': {'statuses_count': 66195, 'entities': {'description': {'urls': []}}, 'default_profile': False, 'profile_text_color': '000000', 'name': 'Python Flux', 'profile_use_background_image': False, 'notifications': False, 'profile_link_color': '1B95E0', 'friends_count': 1859, 'profile_image_url': 'http://pbs.twimg.com/profile_images/726714034066706433/5NWdOzpJ_normal.jpg', 'contributors_enabled': False, 'profile_image_url ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'en'}, user=User(statuses_count=807, profile_background_image_url=None, profile_text_color='333333', name='Learn Python', profile_use_background_image=True, friends_count=1866, default_profile=True, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/903124545426546692/ihFOtO1V_normal.jpg', notifications=False, followers_count=733, id=840884925763002368, translator_type='none', profile_background_color='F5F8FA', time_zone='Pacific Time (US & Canada)', geo_enabled=False, protected=False, location='Texas, USA', _json={'statuses_count': 807, 'entities': {'url': {'urls': [{'display_url': 'edusavecoupon.net', 'expanded_url': 'https://edusavecoupon.net/', 'url': 'https://t.co/X6JFwQdKYU', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'Learn Python', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 1866, 'profile_image_url': 'http://pbs.twimg.com/profile_images/903124545426546692/ihFOtO1V_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/903124545426546692/ihFOtO1V_normal.jpg', 'has_extended_profile': False, 'favourites_count': 0, 'default_profile_image': False, 'time_zone': 'Pacific Time (US & Canada)', 'followers_count': 733, 'created_at': 'Sun Mar 12 11:19:24 +0000 2017', 'listed_count': 7, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': None, 'profile_background_color': 'F5F8FA', 'url': 'https://t.co/X6JFwQdKYU', 'utc_offset': -28800, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/840884925763002368/1504156742', 'lang': 'en', 'geo_enabled': False, 'profile_background_image_url_https': None, 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'Texas, USA', 'screen_name': 'LearntoPython', 'profile_background_tile': False, 'id_str': '840884925763002368', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'is_translator': False, 'id': 840884925763002368, 'follow_request_sent': False, 'description': 'Here to share events, tutorials, courses, books... related to #python #django #flask #programming #code #webdev #development'}, profile_image_url='http://pbs.twimg.com/profile_images/903124545426546692/ihFOtO1V_normal.jpg', profile_sidebar_fill_color='DDEEF6', following=False, follow_request_sent=False, description='Here to share events, tutorials, courses, books... related to #python #django #flask #programming #code #webdev #development', entities={'url': {'urls': [{'display_url': 'edusavecoupon.net', 'expanded_url': 'https://edusavecoupon.net/', 'url': 'https://t.co/X6JFwQdKYU', 'indices': [0, 23]}]}, 'description': {'urls': []}}, id_str='840884925763002368', profile_link_color='1DA1F2', favourites_count=0, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/840884925763002368/1504156742', created_at=datetime.datetime(2017, 3, 12, 11, 19, 24), listed_count=7, verified=False, has_extended_profile=False, url='https://t.co/X6JFwQdKYU', _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https=None, is_translation_enabled=False, screen_name='LearntoPython', profile_background_tile=False, utc_offset=-28800, profile_sidebar_border_color='C0DEED', is_translator=False), entities={'user_mentions': [], 'media': [{'indices': [98, 121], 'media_url': 'http://pbs.twimg.com/media/DV1LWoKVAAAfc3_.jpg', 'display_url': 'pic.twitter.com/4ImFjKJ9Lg', 'url': 'https://t.co/4ImFjKJ9Lg', 'type': 'photo', 'sizes': {'large': {'h': 422, 'w': 750, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}, 'small': {'h': 383, 'w': 680, 'resize': 'fit'}, 'medium': {'h': 422, 'w': 750, 'resize': 'fit'}}, 'id_str': '963008747437096960', 'expanded_url': 'https://twitter.com/LearntoPython/status/963 ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'en'}, user=User(statuses_count=12788, profile_background_image_url='http://pbs.twimg.com/profile_background_images/503843339897032706/ZyYIOyZp.png', profile_text_color='333333', name="Lily's Social Media and Online Training", profile_use_background_image=True, friends_count=6194, default_profile=False, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/945350300788981760/S12KZcJZ_normal.jpg', notifications=False, followers_count=7123, id=134434122, translator_type='none', profile_background_color='C3D4D1', time_zone='London', geo_enabled=True, protected=False, location='Bradford, Yorkshire', _json={'statuses_count': 12788, 'entities': {'url': {'urls': [{'display_url': 'media4you.social', 'expanded_url': 'https://media4you.social', 'url': 'https://t.co/nlEdrPKCEK', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'default_profile': False, 'profile_text_color': '333333', 'name': "Lily's Social Media and Online Training", 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': 'C9455B', 'friends_count': 6194, 'profile_image_url': 'http://pbs.twimg.com/profile_images/945350300788981760/S12KZcJZ_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/945350300788981760/S12KZcJZ_normal.jpg', 'has_extended_profile': True, 'favourites_count': 1873, 'default_profile_image': False, 'time_zone': 'London', 'followers_count': 7123, 'created_at': 'Sun Apr 18 11:58:09 +0000 2010', 'listed_count': 320, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/503843339897032706/ZyYIOyZp.png', 'profile_background_color': 'C3D4D1', 'url': 'https://t.co/nlEdrPKCEK', 'utc_offset': 0, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/134434122/1416060959', 'lang': 'en', 'geo_enabled': True, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/503843339897032706/ZyYIOyZp.png', 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'Bradford, Yorkshire', 'screen_name': 'byLilyV', 'profile_background_tile': True, 'id_str': '134434122', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'EADEAA', 'is_translator': False, 'id': 134434122, 'follow_request_sent': False, 'description': 'Unless you tell 💬 them, they will not know 😉.\nI can help you say 💋 the right thing 💡 to the right people 🌍, using #socialmedia  📲 🏪 & #online #training'}, profile_image_url='http://pbs.twimg.com/profile_images/945350300788981760/S12KZcJZ_normal.jpg', profile_sidebar_fill_color='EADEAA', following=False, follow_request_sent=False, description='Unless you tell 💬 them, they will not know 😉.\nI can help you say 💋 the right thing 💡 to the right people 🌍, using #socialmedia  📲 🏪 & #online #training', entities={'url': {'urls': [{'display_url': 'media4you.social', 'expanded_url': 'https://media4you.social', 'url': 'https://t.co/nlEdrPKCEK', 'indices': [0, 23]}]}, 'description': {'urls': []}}, id_str='134434122', profile_link_color='C9455B', favourites_count=1873, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/134434122/1416060959', created_at=datetime.datetime(2010, 4, 18, 11, 58, 9), listed_count=320, verified=False, has_extended_profile=True, url='https://t.co/nlEdrPKCEK', _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/503843339897032706/ZyYIOyZp.png', is_translation_enabled=False, screen_name='byLilyV', profile_background_tile=True, utc_offset=0, profile_sidebar_border_color='000000', is_translator=False), entities={'user_mentions': [], 'symbols': [], 'urls': [{'display_url': 'twitter.com/i/web/status/9…', 'expanded_url': 'https://twitter.com/i/web/status/963008667011506176', 'url': 'https://t.co/zNOX ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'en'}, user=User(statuses_count=22, profile_background_image_url=None, profile_text_color='333333', name='Python from Udemy', profile_use_background_image=True, friends_count=283, default_profile=True, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/941144235755044864/S1t2PUTn_normal.jpg', notifications=False, followers_count=81, id=941138176055435265, translator_type='none', profile_background_color='F5F8FA', time_zone='Pacific Time (US & Canada)', geo_enabled=False, protected=False, location='Toronto, Ontario', _json={'statuses_count': 22, 'entities': {'url': {'urls': [{'display_url': 'edusavecoupon.net', 'expanded_url': 'https://edusavecoupon.net/', 'url': 'https://t.co/X6JFwPWa7m', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'Python from Udemy', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 283, 'profile_image_url': 'http://pbs.twimg.com/profile_images/941144235755044864/S1t2PUTn_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/941144235755044864/S1t2PUTn_normal.jpg', 'has_extended_profile': False, 'favourites_count': 0, 'default_profile_image': False, 'time_zone': 'Pacific Time (US & Canada)', 'followers_count': 81, 'created_at': 'Thu Dec 14 02:50:01 +0000 2017', 'listed_count': 0, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': None, 'profile_background_color': 'F5F8FA', 'url': 'https://t.co/X6JFwPWa7m', 'utc_offset': -28800, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/941138176055435265/1513221442', 'lang': 'en', 'geo_enabled': False, 'profile_background_image_url_https': None, 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'Toronto, Ontario', 'screen_name': 'Python_Udemy', 'profile_background_tile': False, 'id_str': '941138176055435265', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'is_translator': False, 'id': 941138176055435265, 'follow_request_sent': False, 'description': '#python #django #flask #programming #development'}, profile_image_url='http://pbs.twimg.com/profile_images/941144235755044864/S1t2PUTn_normal.jpg', profile_sidebar_fill_color='DDEEF6', following=False, follow_request_sent=False, description='#python #django #flask #programming #development', entities={'url': {'urls': [{'display_url': 'edusavecoupon.net', 'expanded_url': 'https://edusavecoupon.net/', 'url': 'https://t.co/X6JFwPWa7m', 'indices': [0, 23]}]}, 'description': {'urls': []}}, id_str='941138176055435265', profile_link_color='1DA1F2', favourites_count=0, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/941138176055435265/1513221442', created_at=datetime.datetime(2017, 12, 14, 2, 50, 1), listed_count=0, verified=False, has_extended_profile=False, url='https://t.co/X6JFwPWa7m', _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https=None, is_translation_enabled=False, screen_name='Python_Udemy', profile_background_tile=False, utc_offset=-28800, profile_sidebar_border_color='C0DEED', is_translator=False), entities={'user_mentions': [], 'media': [{'indices': [105, 128], 'media_url': 'http://pbs.twimg.com/media/DV1LRQlVQAETBvR.jpg', 'display_url': 'pic.twitter.com/XFwdm5yXYt', 'url': 'https://t.co/XFwdm5yXYt', 'type': 'photo', 'sizes': {'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}, 'small': {'h': 383, 'w': 680, 'resize': 'fit'}, 'medium': {'h': 422, 'w': 750, 'resize': 'fit'}, 'large': {'h': 422, 'w': 750, 'resize': 'fit'}}, 'id_str': '963008655208562689', 'expanded_url': 'https://twitter.com/Python_Udemy/status/963008657532375040/photo/1', 'media_url_https': 'https://pbs.twimg.com/media/DV1LRQlVQAETBvR.jpg', 'id': 963008655208562689}], 'symbols': [],  ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'en'}, user=User(statuses_count=241, profile_background_image_url=None, profile_text_color='333333', name='Hervé Beraud', profile_use_background_image=True, friends_count=93, default_profile=True, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/912587631841726464/VDaa2CqU_normal.jpg', notifications=False, followers_count=30, id=908325476128772096, translator_type='none', profile_background_color='F5F8FA', time_zone='Pacific Time (US & Canada)', geo_enabled=False, protected=False, location='Toulouse, France', _json={'statuses_count': 241, 'entities': {'url': {'urls': [{'display_url': 'github.com/4383', 'expanded_url': 'https://github.com/4383', 'url': 'https://t.co/xK8FSjivGQ', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'Hervé Beraud', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 93, 'profile_image_url': 'http://pbs.twimg.com/profile_images/912587631841726464/VDaa2CqU_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/912587631841726464/VDaa2CqU_normal.jpg', 'has_extended_profile': True, 'favourites_count': 312, 'default_profile_image': False, 'time_zone': 'Pacific Time (US & Canada)', 'followers_count': 30, 'created_at': 'Thu Sep 14 13:44:04 +0000 2017', 'listed_count': 1, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': None, 'profile_background_color': 'F5F8FA', 'url': 'https://t.co/xK8FSjivGQ', 'utc_offset': -28800, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/908325476128772096/1508270160', 'lang': 'fr', 'geo_enabled': False, 'profile_background_image_url_https': None, 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'Toulouse, France', 'screen_name': '4383hberaud', 'profile_background_tile': False, 'id_str': '908325476128772096', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'is_translator': False, 'id': 908325476128772096, 'follow_request_sent': False, 'description': 'DevOps | Time is a store of value much higher than any precious currency or material. Throughout our lives time acquires with money. DevOps make time!'}, profile_image_url='http://pbs.twimg.com/profile_images/912587631841726464/VDaa2CqU_normal.jpg', profile_sidebar_fill_color='DDEEF6', following=False, follow_request_sent=False, description='DevOps | Time is a store of value much higher than any precious currency or material. Throughout our lives time acquires with money. DevOps make time!', entities={'url': {'urls': [{'display_url': 'github.com/4383', 'expanded_url': 'https://github.com/4383', 'url': 'https://t.co/xK8FSjivGQ', 'indices': [0, 23]}]}, 'description': {'urls': []}}, id_str='908325476128772096', profile_link_color='1DA1F2', favourites_count=312, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/908325476128772096/1508270160', created_at=datetime.datetime(2017, 9, 14, 13, 44, 4), listed_count=1, verified=False, has_extended_profile=True, url='https://t.co/xK8FSjivGQ', _api=<tweepy.api.API object at 0x114514da0>, lang='fr', profile_background_image_url_https=None, is_translation_enabled=False, screen_name='4383hberaud', profile_background_tile=False, utc_offset=-28800, profile_sidebar_border_color='C0DEED', is_translator=False), entities={'user_mentions': [{'name': 'Julien Danjou', 'id_str': '324491552', 'indices': [3, 13], 'screen_name': 'juldanjou', 'id': 324491552}], 'symbols': [], 'urls': [{'display_url': 'julien.danjou.info/blog/2018/scal…', 'expanded_url': 'https://julien.danjou.info/blog/2018/scaling-python-application-asyncio', 'url': 'https://t.co/D9QEQrMg8Y', 'indices': [107, 130]}], 'hashtags': [{'indices': [131, 138], 'text': 'python'}]}, created_at=datetime.datetime(2018, 2, 12, 11,  ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'es'}, user=User(statuses_count=348, profile_background_image_url='http://pbs.twimg.com/profile_background_images/253346097/wind-turbine.jpg', profile_text_color='333333', name='Koldo Pina', profile_use_background_image=True, friends_count=354, default_profile=False, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/1353514652/1920_Water-Atomic-Bombm_normal.jpg', notifications=False, followers_count=68, id=56506824, translator_type='none', profile_background_color='9AE4E8', time_zone='Madrid', geo_enabled=False, protected=False, location='Madrid, Spain', _json={'statuses_count': 348, 'entities': {'description': {'urls': []}}, 'default_profile': False, 'profile_text_color': '333333', 'name': 'Koldo Pina', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '0084B4', 'friends_count': 354, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1353514652/1920_Water-Atomic-Bombm_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1353514652/1920_Water-Atomic-Bombm_normal.jpg', 'has_extended_profile': False, 'favourites_count': 11, 'default_profile_image': False, 'time_zone': 'Madrid', 'followers_count': 68, 'created_at': 'Mon Jul 13 21:58:26 +0000 2009', 'listed_count': 2, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/253346097/wind-turbine.jpg', 'profile_background_color': '9AE4E8', 'url': None, 'utc_offset': 3600, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/56506824/1515352038', 'lang': 'en', 'geo_enabled': False, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/253346097/wind-turbine.jpg', 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'Madrid, Spain', 'screen_name': 'Kholdo', 'profile_background_tile': True, 'id_str': '56506824', 'profile_sidebar_border_color': 'B3B3B3', 'profile_sidebar_fill_color': 'C2C2C2', 'is_translator': False, 'id': 56506824, 'follow_request_sent': False, 'description': ''}, profile_image_url='http://pbs.twimg.com/profile_images/1353514652/1920_Water-Atomic-Bombm_normal.jpg', profile_sidebar_fill_color='C2C2C2', following=False, follow_request_sent=False, description='', entities={'description': {'urls': []}}, id_str='56506824', profile_link_color='0084B4', favourites_count=11, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/56506824/1515352038', created_at=datetime.datetime(2009, 7, 13, 21, 58, 26), listed_count=2, verified=False, has_extended_profile=False, url=None, _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/253346097/wind-turbine.jpg', is_translation_enabled=False, screen_name='Kholdo', profile_background_tile=True, utc_offset=3600, profile_sidebar_border_color='B3B3B3', is_translator=False), entities={'user_mentions': [], 'symbols': [], 'urls': [{'display_url': 'ow.ly/KIbT30ikEda', 'expanded_url': 'http://ow.ly/KIbT30ikEda', 'url': 'https://t.co/rSOhKN2NCJ', 'indices': [66, 89]}, {'display_url': 'twitter.com/i/web/status/9…', 'expanded_url': 'https://twitter.com/i/web/status/963008585428013056', 'url': 'https://t.co/MtMKP9zuMk', 'indices': [106, 129]}], 'hashtags': [{'indices': [90, 104], 'text': 'DataScientist'}]}, created_at=datetime.datetime(2018, 2, 12, 11, 15, 13), is_quote_status=False, _json={'user': {'statuses_count': 348, 'entities': {'description': {'urls': []}}, 'default_profile': False, 'profile_text_color': '333333', 'name': 'Koldo Pina', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '0084B4', 'friends_count': 354, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1353514652/1920_Water-Atomic-Bombm_normal.jpg', 'contributors_enabled': False, 'pr ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'da'}, user=User(statuses_count=22, profile_background_image_url=None, profile_text_color='333333', name='Programming Python', profile_use_background_image=True, friends_count=462, default_profile=True, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/941143993563451392/C3kJfryq_normal.jpg', notifications=False, followers_count=225, id=941138149488635904, translator_type='none', profile_background_color='F5F8FA', time_zone='Pacific Time (US & Canada)', geo_enabled=False, protected=False, location='Brussel, België', _json={'statuses_count': 22, 'entities': {'url': {'urls': [{'display_url': 'edusavecoupon.net', 'expanded_url': 'https://edusavecoupon.net/', 'url': 'https://t.co/X6JFwPWa7m', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'Programming Python', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 462, 'profile_image_url': 'http://pbs.twimg.com/profile_images/941143993563451392/C3kJfryq_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/941143993563451392/C3kJfryq_normal.jpg', 'has_extended_profile': False, 'favourites_count': 0, 'default_profile_image': False, 'time_zone': 'Pacific Time (US & Canada)', 'followers_count': 225, 'created_at': 'Thu Dec 14 02:49:55 +0000 2017', 'listed_count': 0, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': None, 'profile_background_color': 'F5F8FA', 'url': 'https://t.co/X6JFwPWa7m', 'utc_offset': -28800, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/941138149488635904/1513221437', 'lang': 'en', 'geo_enabled': False, 'profile_background_image_url_https': None, 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'Brussel, België', 'screen_name': 'Python_programz', 'profile_background_tile': False, 'id_str': '941138149488635904', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'is_translator': False, 'id': 941138149488635904, 'follow_request_sent': False, 'description': 'I will share events, tutorials, courses, books... related to #python #django #flask #programming #code #webdev #development'}, profile_image_url='http://pbs.twimg.com/profile_images/941143993563451392/C3kJfryq_normal.jpg', profile_sidebar_fill_color='DDEEF6', following=False, follow_request_sent=False, description='I will share events, tutorials, courses, books... related to #python #django #flask #programming #code #webdev #development', entities={'url': {'urls': [{'display_url': 'edusavecoupon.net', 'expanded_url': 'https://edusavecoupon.net/', 'url': 'https://t.co/X6JFwPWa7m', 'indices': [0, 23]}]}, 'description': {'urls': []}}, id_str='941138149488635904', profile_link_color='1DA1F2', favourites_count=0, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/941138149488635904/1513221437', created_at=datetime.datetime(2017, 12, 14, 2, 49, 55), listed_count=0, verified=False, has_extended_profile=False, url='https://t.co/X6JFwPWa7m', _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https=None, is_translation_enabled=False, screen_name='Python_programz', profile_background_tile=False, utc_offset=-28800, profile_sidebar_border_color='C0DEED', is_translator=False), entities={'user_mentions': [], 'media': [{'indices': [88, 111], 'media_url': 'http://pbs.twimg.com/media/DV1LGkxV4AAIY40.jpg', 'display_url': 'pic.twitter.com/Axye2cmG6R', 'url': 'https://t.co/Axye2cmG6R', 'type': 'photo', 'sizes': {'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}, 'small': {'h': 383, 'w': 680, 'resize': 'fit'}, 'medium': {'h': 422, 'w': 750, 'resize': 'fit'}, 'large': {'h': 422, 'w': 750, 'resize': 'fit'}}, 'id_str': '963008471649083392', 'expanded_url': 'https://twitter.com/Pyth ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'und'}, user=User(statuses_count=895, profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_text_color='333333', name='HEBBARE MANIKANTARAO', profile_use_background_image=True, friends_count=106, default_profile=True, contributors_enabled=False, profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', notifications=False, followers_count=7, id=3242985085, translator_type='none', profile_background_color='C0DEED', time_zone=None, geo_enabled=False, protected=False, location='', _json={'statuses_count': 895, 'entities': {'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'HEBBARE MANIKANTARAO', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 106, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'contributors_enabled': False, 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'has_extended_profile': False, 'favourites_count': 1, 'default_profile_image': True, 'time_zone': None, 'followers_count': 7, 'created_at': 'Fri Jun 12 05:14:31 +0000 2015', 'listed_count': 0, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_color': 'C0DEED', 'url': None, 'utc_offset': None, 'lang': 'en', 'geo_enabled': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': '', 'screen_name': 'india708', 'profile_background_tile': False, 'id_str': '3242985085', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'is_translator': False, 'id': 3242985085, 'follow_request_sent': False, 'description': ''}, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', profile_sidebar_fill_color='DDEEF6', following=False, follow_request_sent=False, description='', entities={'description': {'urls': []}}, id_str='3242985085', profile_link_color='1DA1F2', favourites_count=1, default_profile_image=True, created_at=datetime.datetime(2015, 6, 12, 5, 14, 31), listed_count=0, verified=False, has_extended_profile=False, url=None, _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', is_translation_enabled=False, screen_name='india708', profile_background_tile=False, utc_offset=None, profile_sidebar_border_color='C0DEED', is_translator=False), entities={'user_mentions': [], 'symbols': [], 'urls': [], 'hashtags': [{'indices': [2, 9], 'text': 'python'}, {'indices': [10, 20], 'text': 'Microsoft'}]}, created_at=datetime.datetime(2018, 2, 12, 11, 14, 39), is_quote_status=False, _json={'user': {'statuses_count': 895, 'entities': {'description': {'urls': []}}, 'default_profile': True, 'profile_text_color': '333333', 'name': 'HEBBARE MANIKANTARAO', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '1DA1F2', 'friends_count': 106, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'contributors_enabled': False, 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'has_extended_profile': False, 'favourites_count': 1, 'default_profile_image': True, 'time_zone': None, 'followers_count': 7, 'created_at': 'Fri Jun 12 05:14:31 +0000 2015', 'listed_count': 0, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_color': 'C0DEED', 'url': None, 'utc_offset': None, 'lang': 'en', 'geo_enabled': False, 'profile_background_ima ...
#  Status(metadata={'result_type': 'recent', 'iso_language_code': 'en'}, user=User(statuses_count=6359, profile_background_image_url='http://pbs.twimg.com/profile_background_images/342621472/Screen_shot_2011-10-07_at_7.17.45_PM.png', profile_text_color='666666', name='N.B.O', profile_use_background_image=True, friends_count=1316, default_profile=False, contributors_enabled=False, profile_image_url_https='https://pbs.twimg.com/profile_images/922582571875209217/2IOUP-ss_normal.jpg', notifications=False, followers_count=522, id=27726465, translator_type='none', profile_background_color='1A1B1F', time_zone='Kuwait', geo_enabled=True, protected=False, location='The Capital, Kuwait', _json={'statuses_count': 6359, 'entities': {'description': {'urls': []}}, 'default_profile': False, 'profile_text_color': '666666', 'name': 'N.B.O', 'profile_use_background_image': True, 'notifications': False, 'profile_link_color': '2FC2EF', 'friends_count': 1316, 'profile_image_url': 'http://pbs.twimg.com/profile_images/922582571875209217/2IOUP-ss_normal.jpg', 'contributors_enabled': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/922582571875209217/2IOUP-ss_normal.jpg', 'has_extended_profile': True, 'favourites_count': 6286, 'default_profile_image': False, 'time_zone': 'Kuwait', 'followers_count': 522, 'created_at': 'Mon Mar 30 20:54:43 +0000 2009', 'listed_count': 35, 'verified': False, 'translator_type': 'none', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/342621472/Screen_shot_2011-10-07_at_7.17.45_PM.png', 'profile_background_color': '1A1B1F', 'url': None, 'utc_offset': 10800, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/27726465/1467566899', 'lang': 'en', 'geo_enabled': True, 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/342621472/Screen_shot_2011-10-07_at_7.17.45_PM.png', 'is_translation_enabled': False, 'protected': False, 'following': False, 'location': 'The Capital, Kuwait', 'screen_name': 'NASSER_B_O', 'profile_background_tile': True, 'id_str': '27726465', 'profile_sidebar_border_color': '181A1E', 'profile_sidebar_fill_color': '252429', 'is_translator': False, 'id': 27726465, 'follow_request_sent': False, 'description': 'goth.. computer engineer web developer ..PYTHONISTA.... Hacker.. CEHV9.. social engineer.. artist.. designer.. master hypnotist.. trainer.. comics..'}, profile_image_url='http://pbs.twimg.com/profile_images/922582571875209217/2IOUP-ss_normal.jpg', profile_sidebar_fill_color='252429', following=False, follow_request_sent=False, description='goth.. computer engineer web developer ..PYTHONISTA.... Hacker.. CEHV9.. social engineer.. artist.. designer.. master hypnotist.. trainer.. comics..', entities={'description': {'urls': []}}, id_str='27726465', profile_link_color='2FC2EF', favourites_count=6286, default_profile_image=False, profile_banner_url='https://pbs.twimg.com/profile_banners/27726465/1467566899', created_at=datetime.datetime(2009, 3, 30, 20, 54, 43), listed_count=35, verified=False, has_extended_profile=True, url=None, _api=<tweepy.api.API object at 0x114514da0>, lang='en', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/342621472/Screen_shot_2011-10-07_at_7.17.45_PM.png', is_translation_enabled=False, screen_name='NASSER_B_O', profile_background_tile=True, utc_offset=10800, profile_sidebar_border_color='181A1E', is_translator=False), entities={'user_mentions': [{'name': 'Python Flux', 'id_str': '726709023563747328', 'indices': [3, 14], 'screen_name': 'pythonbot_', 'id': 726709023563747328}], 'symbols': [], 'urls': [{'display_url': 'zpy.io/55737022', 'expanded_url': 'http://zpy.io/55737022', 'url': 'https://t.co/kZdZqaY5o3', 'indices': [88, 111]}], 'hashtags': [{'indices': [112, 119], 'text': 'python'}, {'indices': [120, 132], 'text': 'programming'}]}, created_at=datetime.datetime(2018, 2, 12, 11, 14, 21), is_quote_status=False, _json={'user': {'statuses_count': 6359, ' ...

# %%
# You will then have to parse the results to get the text you want.

for Status in searched_tweets:
    print("User: " + Status.user.screen_name, "Tweet:" + Status.text)
# Out:
# User: rubnvp Tweet:RT @_pi0_: This is not an April fools joke! You can build @vuejs and @nuxt_js apps using #Python / HTML and CSS using this module 😲 Made by…
# User: pythonbot_ Tweet:Mastering Social Media Mining With Python  https://t.co/yONK09frgl #learning #python #pythonbot_
# User: LearntoPython Tweet:Python for Financial Analysis and Algorithmic Trading
# ☞ https://t.co/ob5qrSUz1a
# #python
# S1rhTw2IG https://t.co/4ImFjKJ9Lg
# User: byLilyV Tweet:40 #bestseller #udemy #courses
#
# 13. #Machine Learning A-Z™: Hands-On #Python &amp; #R In #Data #Science… https://t.co/zNOX8lhuy7
# User: Python_Udemy Tweet:Computer Programming For Beginners Learn Python Programming
# ☞ https://t.co/lkgQUAQnx9
# #Python
# BJbmiHFqLM https://t.co/XFwdm5yXYt
# User: 4383hberaud Tweet:RT @juldanjou: Wondering how you can make your application 6x time faster with asyncio? Here's an example:
# https://t.co/D9QEQrMg8Y
# #python…
# User: Kholdo Tweet:Segundo post!, continuando con la agrupación de datos con Python. https://t.co/rSOhKN2NCJ #DataScientist… https://t.co/MtMKP9zuMk
# User: Python_programz Tweet:Mastering Python Data Analysis with Pandas
# ☞ https://t.co/deAy0vngN5
# #Python
# rJZmUSK5Lf https://t.co/Axye2cmG6R
# User: india708 Tweet:👍
# #python
# #Microsoft
# User: NASSER_B_O Tweet:RT @pythonbot_: Beginning Python Visualization: Crafting Visual Transformation Scripts  https://t.co/kZdZqaY5o3 #python #programming #pytho…

# %% [markdown]
# What's in twitter data: https://dev.twitter.com/overview/api/tweets
#
# Incredibly cool: https://dev.twitter.com/overview/api/entities-in-twitter-objects
